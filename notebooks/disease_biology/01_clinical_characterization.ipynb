# %%
from pathlib import Path
import pandas as pd

# root directory of the project
root_dir = Path.cwd().parent.parent

# Load TCGA KIRC clinical data
tcga_clinical_data = pd.read_csv(
    root_dir / "data" / "clinical" / "tcga_kirc_clinical.tsv",
    sep="\t"
)

# Display information about the clinical data
tcga_clinical_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 537 entries, 0 to 536
# Data columns (total 23 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   demographic.days_to_birth           536 non-null    float64
#  1   demographic.gender                  537 non-null    str
#  2   demographic.vital_status            537 non-null    str
#  3   diagnoses.0.ajcc_pathologic_m       534 non-null    str
#  4   diagnoses.0.ajcc_pathologic_n       537 non-null    str
#  5   diagnoses.0.ajcc_pathologic_stage   532 non-null    str
#  6   diagnoses.0.ajcc_pathologic_t       536 non-null    str
#  7   diagnoses.0.days_to_last_follow_up  522 non-null    float64
#  8   diagnoses.0.tumor_grade             519 non-null    str
#  9   diagnoses.1.ajcc_pathologic_m       21 non-null     str
#  10  diagnoses.1.ajcc_pathologic_n       21 non-null     str
#  11  diagnoses.1.ajcc_pathologic_stage   21 non-null     str
#  12  diagnoses.1.ajcc_pathologic_t       23 non-null     str
#  13  diagnoses.1.days_to_last_follow_up  14 non-null     float64
#  14  diagnoses.1.tumor_grade             14 non-null     str
#  15  diagnoses.2.ajcc_pathologic_m       3 non-null      str
#  16  diagnoses.2.ajcc_pathologic_n       3 non-null      str
#  17  diagnoses.2.ajcc_pathologic_stage   3 non-null      str
#  18  diagnoses.2.ajcc_pathologic_t       3 non-null      str
#  19  diagnoses.2.days_to_last_follow_up  1 non-null      float64
#  20  diagnoses.2.tumor_grade             1 non-null      str
#  21  id                                  537 non-null    str
#  22  submitter_id                        537 non-null    str
# dtypes: float64(4), str(19)
# memory usage: 96.6 KB

# %%
# Display the first few rows of the clinical data
print(tcga_clinical_data.head())
# Out:
#    demographic.days_to_birth demographic.gender demographic.vital_status  \
# 0                   -22320.0             female                    Alive
# 1                   -15360.0               male                    Alive
# 2                   -24850.0               male                    Alive
# 3                   -15264.0               male                    Alive
# 4                   -25508.0             female                     Dead
#
#   diagnoses.0.ajcc_pathologic_m diagnoses.0.ajcc_pathologic_n  \
# 0                            M0                            N0
# 1                            M0                            NX
# 2                            M0                            N0
# 3                            M0                            NX
# 4                            M1                            N1
#
#   diagnoses.0.ajcc_pathologic_stage diagnoses.0.ajcc_pathologic_t  \
# 0                           Stage I                           T1b
# 1                           Stage I                           T1a
# 2                           Stage I                           T1b
# 3                           Stage I                           T1a
# 4                          Stage IV                            T4
#
#    diagnoses.0.days_to_last_follow_up diagnoses.0.tumor_grade  \
# 0                              2150.0                      G2
# 1                               211.0                      G3
# 2                              1371.0                      G3
# 3                              1130.0                      G2
# 4                              1714.0                      G4
#
#   diagnoses.1.ajcc_pathologic_m  ... diagnoses.1.days_to_last_follow_up  \
# 0                           NaN  ...                                NaN
# 1                           NaN  ...                                NaN
# 2                           NaN  ...                                NaN
# 3                            MX  ...                                NaN
# 4                           NaN  ...                                NaN
#
#   diagnoses.1.tumor_grade diagnoses.2.ajcc_pathologic_m  \
# 0                     NaN                           NaN
# 1                     NaN                           NaN
# 2                     NaN                           NaN
# 3                     NaN                            MX
# 4                     NaN                           NaN
#
#    diagnoses.2.ajcc_pathologic_n diagnoses.2.ajcc_pathologic_stage  \
# 0                            NaN                               NaN
# 1                            NaN                               NaN
# 2                            NaN                               NaN
# 3                             NX                           Stage I
# 4                            NaN                               NaN
#
#   diagnoses.2.ajcc_pathologic_t diagnoses.2.days_to_last_follow_up  \
# 0                           NaN                                NaN
# 1                           NaN                                NaN
# 2                           NaN                                NaN
# 3                           T1a                                NaN
# 4                           NaN                                NaN
#
#   diagnoses.2.tumor_grade                                    id  submitter_id
# 0                     NaN  fb9bafa5-7133-4955-8156-4eb6763dc8e1  TCGA-B0-5695
# 1                     NaN  33cf0893-0411-4758-aa90-602bfedf0850  TCGA-BP-4807
# 2                     NaN  9245a557-01ea-4446-b9e9-313f6ab18834  TCGA-BP-4995
# 3                     NaN  c6454371-1f84-4e8e-8c3a-2eac8380819e  TCGA-DV-5573
# 4                     NaN  33cd8b05-2b9b-40dd-97a2-40d02e27ee90  TCGA-CJ-4900
#
# [5 rows x 23 columns]
